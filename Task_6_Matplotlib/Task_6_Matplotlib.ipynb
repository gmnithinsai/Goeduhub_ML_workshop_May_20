# %% [markdown]
# # Goeduhub | Task - 6 Matplotlib libray | Reg.ID : GO_STP_2134

# %% [markdown]
# ## This assignment is for visualization using Python Matplotlib Library
#
# - - -
# 1. Load the necessary package for plotting using pyplot from matplotlib.
# - Example - Days(x-axis) represents 8 days and Speed represents a car’s speed.
# - Plot a Basic line plot between days and car speed, put x axis label as days and y axis label as car speed and put title Car Speed Measurement.
#
#          Days=[1,2,3,4,5,6,7,8]
#
#          Speed=[60,62,61,58,56,57,46,63]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
Days=[1,2,3,4,5,6,7,8]
Speed=[60,62,61,58,56,57,46,63]

plt.plot(Days,Speed)
plt.title("Car speed measurement")
plt.xlabel('Days')
plt.ylabel('Car Speed')
plt.show()

# %%
days=np.array([1,2,3,4,5,6,7,8])
speed=np.array([60,62,61,58,56,57,46,63])

# %%
plt.figure(figsize=(12,6))
plt.plot(days,speed)
plt.annotate('start point',xy=(1,60),xycoords='data',xytext=(40,-80),textcoords='offset points',arrowprops=dict(arrowstyle='<|-|>',color='grey',lw=3,ls='--'),horizontalalignment='right',verticalalignment='bottom')
plt.annotate('start point',xy=(8,63),xycoords='data',xytext=(40,-80),textcoords='offset points',arrowprops=dict(arrowstyle='<|-|>',color='grey',lw=3,ls='--'),horizontalalignment='right',verticalalignment='bottom')
# Out:
# Text(40, -80, 'start point')

# %% [markdown]
# __2. Now to above car data apply some string formats  like line style example green dotted line, marker shape like +, change markersize, markerface color etc.__

# %%
plt.figure(figsize=(12,6))
plt.plot(Days,Speed,color='green',linestyle='dashed',marker='o')
plt.title("Car speed measurement")
plt.xlabel('Days')
plt.ylabel('Car Speed')
plt.annotate('Start speed',xy=(1,60),xycoords='data',xytext=(40,-80),textcoords='axes pix',arrowprops=dict(arrowstyle='->',color='grey',lw=3,ls='solid'))
plt.show()

# %%
plt.plot(Days,Speed,color='green',linestyle='dashed',marker='+',markersize=15)
plt.title("Car speed measurement")
plt.xlabel('Days')
plt.ylabel('Car Speed')
plt.show()

# %%
plt.plot(Days,Speed,color='green',linestyle='dashed',marker='o',markerfacecolor='blue')
plt.title("Car speed measurement")
plt.xlabel('Days')
plt.ylabel('Car Speed')
plt.show()

# %% [markdown]
# __3. Plot Axes Labels, Chart title, Legend, Grid in Car minimum, Maximum and average speed in 8 days.__
#
# - days=[1,2,3,4,5,6,7,8]
#
# - max_speed=[80,91,92,88,77,79,76,75]
#
# - min_speed=[42,43,40,42,33,36,34,35]
#
# - avg_speed=[46,58,57,56,40,42,41,36]

# %%
max_speed=[80,91,92,88,77,79,76,75]
min_speed=[42,43,40,42,33,36,34,35]
avg_speed=[46,58,57,56,40,42,41,36]
days=[1,2,3,4,5,6,7,8]


plt.plot(days,max_speed,color='r',marker='o',linestyle='solid',label='Maximum speed')
plt.plot(days,min_speed,color='g',marker='o',linestyle='solid',label='Minimum speed')
plt.plot(days,avg_speed,color='b',marker='o',linestyle='solid',label='average speed')
plt.title('Days vs Average speed,Maximum speed,Minimum speed')
plt.xlabel('Days')
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# __4. Plotting a basic sine graph by adding more features. Adding Multiple plots by Superimposition like cosine wave.__

# %%
x=np.linspace(0,6,100)

y=np.sin(x)

z=np.cos(x)
plt.figure(figsize=(12,6))
plt.plot(x,y,color='r',linestyle=':',linewidth=3,label='Sine wave')
plt.plot(x,z,color='b',linestyle=':',linewidth=3,label='Cos wave')
#plt.annotate('sine wave',xy=(0,0),xycoords='data',xytext=(40,-80),textcoords='axes fraction',arrowprops=dict(arrowstyle='->',color='grey',lw=3,ls='solid'))
plt.legend()
plt.show()

# %% [markdown]
# __5. Plot Simple bar chart showing popularity of Programming Languages.__
#
# - Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
#
# - Popularity = [56, 39, 34, 34, 29]
#
# - Security = [44 ,36 ,55, 50, 42]
#
# Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal bar chart using barh function

# %%
languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
popularity = [56, 39, 34, 34, 29]
security = [44 ,36 ,55, 50, 42]
#plt.subplot(1,1,1)
plt.figure(figsize=(10,5))
plt.bar(languages,popularity,color='lightgreen',width=0.4)
plt.title('Languages and their popularity')
plt.show()
plt.figure(figsize=(10,5))
plt.bar(languages,security,color='lightblue',width=0.4)
plt.title('Languages and security')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.barh(languages,popularity,color='lightgreen')
plt.title('Languages and their popularity')
plt.show()
plt.figure(figsize=(10,5))
plt.barh(languages,security,color='lightblue')
plt.title('Languages and security')
plt.show()

# %%
plt.hist(popularity,color='lightgreen')
plt.title('popularity')
plt.show()

plt.hist(security,color='lightblue')
plt.title('security')
plt.show()

# %% [markdown]
# __6.  Plot Histogram, We have a sample data of Students marks of various Students, we will try to plot number of Students by marks range and try to figure out how many Students are average, below-average and Excellent.__
#
# Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]
#
# Histogram showing Below Average, Average and Execellent distribution
#
# 40-60: Below Average
#
# 60-80: Average
#
# 80-100: Excellent

# %%
marks = np.array([ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64])
plt.figure(figsize=(12,6))
plt.hist(marks,color='lightblue',edgecolor='blue')
plt.xlabel('bins')
plt.ylabel('Marks')
plt.title('Histogram of marks')
plt.vlines([40,60,80,100],ymin=0,ymax=4,linestyle='dashed')

# %%
plt.figure(figsize=(12,6))
plt.hist(marks,bins=[40,60,80,100],color='lightgreen',edgecolor='green')
plt.xlabel('bins')
plt.ylabel('Marks')
plt.title('Histogram of marks')
plt.vlines([40,60,80,100],ymin=0,ymax=8,linestyle='dashed')

# %% [markdown]
# __7.  Titanic Data Set Download Data__
#
#  Load the data file
#
#  (i) Create a pie chart presenting the male/female proportion
#
#  (ii) Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
import pandas as pd
df=pd.read_csv(r'\Goeduhub_ML_Program_May_20\data\titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Gender={'Sex':{'male':0,'female':1}}

# %%
df=df.replace(Gender)

# %%
df['Sex'].isnull().sum()
# Out:
# 0

# %%
df.Sex.value_counts().plot.pie(autopct='%.0f%%',labels=['Male','FEmale'])
plt.show()

# %%
male=df[df['Sex']=='male']
female=df[df['Sex']=='female']

# %%
plt.figure(figsize=(8,10))
plt.scatter(male.Fare,male.Age,label='Male')
plt.scatter(female.Fare,female.Age,color='g',label='Female')
plt.xlabel("Fare")
plt.ylabel('Age')
plt.legend()
